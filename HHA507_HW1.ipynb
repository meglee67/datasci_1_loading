# %% [markdown]
# <a href="https://colab.research.google.com/github/meglee67/datasci_1_loading/blob/main/HHA507_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### **CSV Files**

# %% [markdown]
# 1. Burger King Dataset

# %%
burger_king = pd.read_csv('burger-king-menu.csv')

# %% [markdown]
# Burger King Dataset - First 10 Rows

# %%
burger_king [:10]
# Out:
#                                    Item Category  Calories  Fat (g)  \
# 0                     Whopper® Sandwich  Burgers       660     40.0
# 1         Whopper® Sandwich with Cheese  Burgers       740     46.0
# 2      Bacon & Cheese Whopper® Sandwich  Burgers       790     51.0
# 3              Double Whopper® Sandwich  Burgers       900     58.0
# 4  Double Whopper® Sandwich with Cheese  Burgers       980     64.0
# 5              Triple Whopper® Sandwich  Burgers      1130     75.0
# 6  Triple Whopper® Sandwich with Cheese  Burgers      1220     82.0
# 7                 Whopper JR.® Sandwich  Burgers       310     18.0
# 8                   Bacon King Sandwich  Burgers      1150     79.0
# 9           Cheddar Bacon King Sandwich  Burgers      1190     84.0
#
#    Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# 0               12.0            1.5                90          980
# 1               16.0            2.0               115         1340
# ...

# %% [markdown]
# ### Features
#
# * Items: The name of the item on the Burger King Menu
#
# * Category: What kind of food category the item falls into
#
# * Calories:How many calories the food item has
#
# * Fat: How much fat in grams the item has
#
# * Saturated Fat: How much saturated fat in grams the item has
#
# * Trans Fat: How much trans fat in grams the item has
#
# * Cholesterol: How much cholesterol in milligrams the item has
#
# * Sodium: How much sodium in milligrams the item has
#
# * Sugars: How much sugar in grams the item has
#
# * Protein: How much protein in grams the item has

# %% [markdown]
# 2. McDonalds Dataset

# %%
mcdonalds = pd.read_csv('mcd.csv')

# %% [markdown]
# McDonalds Dataset - First 10 Rows

# %%
mcdonalds [:10]
# Out:
#                       name serving_size  \
# 0             Black Coffee        200ml
# 1        Chicken McNuggets         64g
# 2            Fillet-O-Fish         136g
# 3                 Iced Tea        400ml
# 4                McChicken         173g
# 5  McFlurry (Choco Crunch)      94.29g
# 6          McFlurry (Oreo)      86.79g
# 7          Soft Serve Cone       81.29g
# 8       Spicy Chicken Wrap         257g
# 9       Spicy Paneer Wrap®         250g
#
#                                          ingredients  \
# 0                                                NaN
# 1                                      Chicken bites
# 2  Steamed regular bun, Chunky tartar mayo, Fish ...
# 3                                                NaN
# 4  Quarter bun crown, Veg mayonnaise, Shredded le...
# 5                                Milk fat, Chocolate
# 6                                     Milk fat, Oreo
# 7                Soft serve mix (100% diary product)
# ...

# %% [markdown]
# ### Features
#
# * Name: Name of the item
# * Serving Size: Serving size of the item in grams or ml
# * Ingredients: The ingredients of the item
# * Allergy: Allergens identified in the item
# * Protein: Amount of protein in the item
# * Total_fat: Amount of total fat in the item
# * Sat_fat: Amount of saturated fat in the item
# * Trans_fat: Amount of trans fat in the item
# * Chol: Amount of cholesterol in the item
# * Carbs: Amount of carbohydrates in the item
# * Sodium: Amount of sodium in the item
# * Description: A brief description of the item

# %% [markdown]
# 3. Anime Dataset

# %%
anime = pd.read_csv ('animes.csv')

# %% [markdown]
# Anime Dataset - First 10 Rows

# %%
anime [:10]
# Out:
#      uid                               title  \
# 0  28891             Haikyuu!! Second Season
# 1  23273             Shigatsu wa Kimi no Uso
# 2  34599                       Made in Abyss
# 3   5114    Fullmetal Alchemist: Brotherhood
# 4  31758    Kizumonogatari III: Reiketsu-hen
# 5  37510                   Mob Psycho 100 II
# 6    199       Sen to Chihiro no Kamikakushi
# 7  38000                    Kimetsu no Yaiba
# 8  35247          Owarimonogatari 2nd Season
# 9   2904  Code Geass: Hangyaku no Lelouch R2
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
# 5  ['Action', 'Slice of Life', 'Comedy', 'Superna...
# 6             ['Adventure', 'Supernatural', 'Drama']
# ...

# %% [markdown]
# ### Features
#
# * uid:The ID number of the anime on the website myanimelist
# * Title: The title of the anime
# * Genre: The genre of the anime
# * Aired: The dates on which the anime originally aired
# * Episodes: How many episodes the anime has
# * Ranked: The anime ranking on myanimelist
# * Score: The score the anime recieved on myanimelist
# * Link: A link to the show's page on myanimelist

# %% [markdown]
# ### **XLSV Files**

# %% [markdown]
# 1. USDA National Nutrient Dataset

# %%
nutrients = pd.read_excel ('Nutrient.xlsx')

# %% [markdown]
# USDA National Nutrient Dataset - First 10 Rows

# %%
nutrients [:10]
# Out:
#                 Shrt_Desc  Protein_(g)  Carbohydrt_(g)  Calcium_(mg)  \
# 0        BUTTER,WITH SALT         0.85            0.06            24
# 1  BUTTER,WHIPPED,W/ SALT         0.49            2.87            23
# 2    BUTTER OIL,ANHYDROUS         0.28            0.00             4
# 3             CHEESE,BLUE        21.40            2.34           528
# 4            CHEESE,BRICK        23.24            2.79           674
# 5             CHEESE,BRIE        20.75            0.45           184
# 6        CHEESE,CAMEMBERT        19.80            0.46           388
# 7          CHEESE,CARAWAY        25.18            3.06           673
# 8          CHEESE,CHEDDAR        22.87            3.09           710
# 9         CHEESE,CHESHIRE        23.37            4.78           643
#
#    Sodium_(mg)  Vit_B12_(µg)  Cholestrl_(mg)
# 0          643          0.17             215
# 1          583          0.07             225
# 2            2          0.01             256
# ...

# %% [markdown]
# ### Features
#
# * Shrt_Desc: A short description of the food item
# * Protein_(g): How much protein in grams the food item has
# * Carbohydrt_(g):How much carbohydrates in grams the food item has
# * Calcium_(mg): How much calcium in milligrams the food item has
# * Sodium_(mg): How much sodium in milligrams the food item has
# * Vit_B12_(µg): How much vitamin B12 in in micrograms the food item has
# * Cholestrl_(mg): How much cholesterol in milligrams the food item has

# %% [markdown]
# 2. Fifa World Cup 2022 Player Statistics Dataset

# %%
fifa = pd.read_excel ('FIFA.xlsx')

# %% [markdown]
# Fifa World Cup 2022 Player Statistics Dataset - First 10 Rows

# %%
fifa [:10]
# Out:
#   Nationality   FIFA Ranking  National Team Kit Sponsor  \
# 0    Argentina              2                    Adidas
# 1    Argentina              2                    Adidas
# 2    Argentina              2                    Adidas
# 3    Argentina              2                    Adidas
# 4    Argentina              2                    Adidas
# 5    Argentina              2                    Adidas
# 6    Argentina              2                    Adidas
# 7    Argentina              2                    Adidas
# 8    Argentina              2                    Adidas
# 9    Argentina              2                    Adidas
#
#    National Team Jersey Number           Player DOB            Club   \
# 0                         23.0  1992-09-02 00:00:00      Aston Villa
# 1                          1.0  1986-10-16 00:00:00            River
# 2                         12.0  1992-05-20 00:00:00       Villarreal
# ...

# %% [markdown]
# ### Features
#
# * Nationality: The nationality of the player
# * Fifa Ranking: The team to which the player belongs Fifa ranking
# * National Team Kit Sponsor: The brand that sponsors the team kit
# * National Team Jersey Number: The jersey number of the national team member
# * Player DOB: The date of birth of the player
# * Club: The club the player belongs to
# * Player Name: The name of the player
# * Brand Sponsor/Brand Used: The brand that the player personally is sponsored by or uses

# %% [markdown]
# 3. Fake Employee Dataset

# %%
employee = pd.read_excel ('Employee.xlsx')

# %% [markdown]
# Fake Employee Dataset - First 10 Rows

# %%
employee [:10]
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female   55 2016-04-08         141604
# 1           Manufacturing    Male   59 1997-11-29          99975
# ...

# %% [markdown]
# ### Features
#
# * EEID: Employee ID
# * Full Name:The full name of the employee
# * Job Title: Job title of the employee
# * Department: The department the employee works in
# * Business Unit: The business unit the employee works in
# * Gender: The gender of the employee
# * Age: The age of the employee
# * Hire Date: The date the employee was hired
# * Annual Salary: The annual salary of the employee
# * Country: The country from which the Employee is from

# %% [markdown]
# ### **JSON Files**

# %% [markdown]
# 1. One Piece Dataset

# %%
pokedex = pd.read_json('One Piece json.json')

# %% [markdown]
# One Piece Dataset - First 10 Rows

# %%
pokedex [:10]
# Out:
#    Unnamed: 0    rank trend  season  episode  \
# 0           0  24,129    18       1        1
# 1           1  29,290    11       1        2
# 2           2  32,043     7       1        3
# 3           3  28,818     8       1        4
# 4           4  37,113     4       1        5
# 5           5  36,209     4       1        6
# 6           6  37,648     4       1        7
# 7           7  38,371     6       1        8
# 8           8  42,249     5       1        9
# 9           9  41,829     4       1       10
#
#                                                 name  start total_votes  \
# 0  I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1  The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2  Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
# ...

# %% [markdown]
# ### Features
#
# * This dataset was pulled from ratinggraph.com where users can vote and rate tv shows, motives, etc.
# * Rank: Episode rank (Rank is based on the average number of votes per episode adjusted with the average rating)
# * Trend: Episode trend (trend represents the amount of new votes submitted during the past 7 days)
# * Season: What season the episode is from
# * Episode: Episode number
# * Name: The name of the episode
# * Start: The year the episode aired
# * Total_votes: Total number of votes for the episode
# * Average_rating: Average rating of the episode

# %% [markdown]
# 2. Wine Reviews Dataset

# %%
wine = pd.read_json ('wine.json')

# %% [markdown]
# Wine Reviews Dataset - First 10 Rows

# %%
wine [:10]
# Out:
#    points                                              title  \
# 0      87                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1      87      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2      87      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3      87  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4      87  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5      87  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6      87   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7      87              Trimbach 2012 Gewurztraminer (Alsace)
# 8      87  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 9      87  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
#
#                                          description         taster_name  \
# 0  Aromas include tropical fruit, broom, brimston...       Kerin O’Keefe
# 1  This is ripe and fruity, a wine that is smooth...          Roger Voss
# ...

# %% [markdown]
# ### Features
#
# * Points: The number of points WineEnthusiast rated the wine on a scale of 1-100
# * Title: The name of the wine
# * Description:A short description of the wine
# * Taster_name: The name of the taster of the wine
# * Taster_twitter_handle: The taster's twitter handle
# * Price: The price of the wine
# * Designation: The vineyard within the winery where the grapes that made the wine are from
# * Variety: What kind of wine it is
# * Region_1: The wine growing area in a province or state
# * Region_2: Sometimes there are more specific regions specified within a wine growing area, this identifies it
# * Province: The province or state that the wine is from
# * Country: What country the wine is from
# * Winery: What winery the wine is from

# %% [markdown]
# 3. Game of Thrones Season 1 Subtitles Dataset

# %%
GOT = pd.read_json('season1.json')

# %% [markdown]
# Game of Thrones Season 1 Subtitles Dataset - First 10 Rows

# %%
GOT [:10]
# Out:
#            Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                           Easy, boy.
# 10             Our orders were to track the wildlings.
# 100                       - Right. Give it here. - No!
# 101                               Put away your blade.
# 102  - I take orders from your father, not you. - P...
# 103                                   I'm sorry, Bran.
# 104                                        Lord Stark?
# 105                               There are five pups.
# 106                One for each of the Stark children.
# 107           The direwolf is the sigil of your house.
#
#               Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                            You need to drink, child.
# 10                   The Dothraki believe that one day
# 100                               Such a little thing.
# 101                           A bird without feathers.
# 102                    They came to take his body away
# ...

# %% [markdown]
# ### Features
#
# * The numbers on the left most side are dialouge numbers. According to the user who published the dataset "Each season has data about all the episodes. Each episode has all the dialogues, where each key is the dialogue number. Since this was exported as a python dictionary, the dialogue numbers are in random order".
#
# * On the top of each column, you can see the season number and episode number, along with the title of the episode.
#
# * Then consequently in each column is the subtitle for a line of dialouge.
